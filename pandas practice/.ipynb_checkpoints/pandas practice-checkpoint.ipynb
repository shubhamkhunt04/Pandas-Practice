# %%
import numpy as np
import pandas as pd

# %%
dict1 = {
    "name":['shubham','khunt','ankit','harshid'],
    "marks":[95,85,75,65],
    "city":['surat','pune','bhopal','surat']
}

# %%
dict1
# Out:
# {'name': ['shubham', 'khunt', 'ankit', 'harshid'],
#  'marks': [95, 85, 75, 65],
#  'city': ['surat', 'pune', 'bhopal', 'surat']}

# %%
df = pd.DataFrame(dict1)

# %%
df
# Out:
#       name  marks    city
# 0  shubham     95   surat
# 1    khunt     85    pune
# 2    ankit     75  bhopal
# 3  harshid     65   surat

# %%
df.to_csv('shubhaminfo.csv')

# %%
df.to_csv('newshubhaminfo.csv',index=False)

# %%
df.head(2)
# Out:
#       name  marks   city
# 0  shubham     95  surat
# 1    khunt     85   pune

# %%
df.tail(2)
# Out:
#       name  marks    city
# 2    ankit     75  bhopal
# 3  harshid     65   surat

# %%
df.head()
# Out:
#       name  marks    city
# 0  shubham     95   surat
# 1    khunt     85    pune
# 2    ankit     75  bhopal
# 3  harshid     65   surat

# %%
df.tail()
# Out:
#       name  marks    city
# 0  shubham     95   surat
# 1    khunt     85    pune
# 2    ankit     75  bhopal
# 3  harshid     65   surat

# %%
df.describe()
# Out:
#            marks
# count   4.000000
# mean   80.000000
# std    12.909944
# min    65.000000
# 25%    72.500000
# 50%    80.000000
# 75%    87.500000
# max    95.000000

# %%
df.mean()
# Out:
# marks    80.0
# dtype: float64

# %%
df.count()
# Out:
# name     4
# marks    4
# city     4
# dtype: int64

# %%
shubham = pd.read_csv('readme.csv')

# %%
shubham
# Out:
#    index     name  marks  age college    branch
# 0      0  shubham     95   19   CGPIT  computer
# 1      1    khunt     85   20    FETR        IT
# 2      2    ankit     75   21   BMIIT      M.sc
# 3      3  harshid     65   22   CKPTW  computer

# %%
shubham['name']
# Out:
# 0    shubham
# 1      khunt
# 2      ankit
# 3    harshid
# Name: name, dtype: object

# %%
shubham['marks']
# Out:
# 0    95
# 1    85
# 2    75
# 3    65
# Name: marks, dtype: int64

# %%
shubham['branch']
# Out:
# 0    computer
# 1          IT
# 2        M.sc
# 3    computer
# Name: branch, dtype: object

# %%
shubham['college'] = "IIT"

# %%
shubham
# Out:
#    index     name  marks  age college    branch
# 0      0  shubham     95   19     IIT  computer
# 1      1    khunt     85   20     IIT        IT
# 2      2    ankit     75   21     IIT      M.sc
# 3      3  harshid     65   22     IIT  computer

# %%
shubham['marks'][0]
# Out:
# 95

# %%
shubham['marks'][1]
# Out:
# 85

# %%
shubham['marks'][0] =  90
# Out:
# c:\users\shubham\appdata\local\programs\python\python37-32\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
shubham
# Out:
#    index     name  marks  age college    branch
# 0      0  shubham     90   19     IIT  computer
# 1      1    khunt     85   20     IIT        IT
# 2      2    ankit     75   21     IIT      M.sc
# 3      3  harshid     65   22     IIT  computer

# %%
shubham.to_csv('newreadme.csv',index = False)

# %%
shubham.index = ['one','two','three','four']

# %%
shubham
# Out:
#        index     name  marks  age college    branch
# one        0  shubham     90   19     IIT  computer
# two        1    khunt     85   20     IIT        IT
# three      2    ankit     75   21     IIT      M.sc
# four       3  harshid     65   22     IIT  computer

# %% [markdown]
# # Pandas has two type of data structures
#
# **(1) DataFrame**
# **(2) Series**

# %%
df['name']
# Out:
# 0    shubham
# 1      khunt
# 2      ankit
# 3    harshid
# Name: name, dtype: object

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df['name'])
# Out:
# pandas.core.series.Series

# %%
ser = pd.Series(np.random.rand
#
# [100 rows x 5 columns]

# %%
newdf.head()
# Out:
#           0         1         2         3         4
# 0  0.333333  0.794252  0.080251  0.929285  0.264517
# 1  0.444444  0.576179  0.856053  0.792471  0.120234
# 2  0.397942  0.836594  0.052836  0.302841  0.855034
# 3  0.827553  0.704875  0.169747  0.435392  0.359005
# 4  0.626744  0.391912  0.809596  0.246168  0.430423

# %%
newdf[0]
# Out:
# 0      0.333333
# 1      0.444444
# 2      0.397942
# 3      0.827553
# 4      0.626744
#         ...
# 95     0.823605
# 96    0.0948171
# 97    0.0184986
# 98      0.63652
# 99     0.278624
# Name: 0, Length: 100, dtype: object

# %%
newdf[0][0]
# Out:
# 0.33333333

# %%
type(newdf[0])
# Out:
# pandas.core.series.Series

# %%
newdf1 = newdf

# %%
newdf1
# Out:
#             0         1         2         3         4
# 0    0.333333  0.794252  0.080251  0.929285  0.264517
# 1    0.444444  0.576179  0.856053  0.792471  0.120234
# 2    0.397942  0.836594  0.052836  0.302841  0.855034
# 3    0.827553  0.704875  0.169747  0.435392  0.359005
# 4    0.626744  0.391912  0.809596  0.246168  0.430423
# ..        ...       ...       ...       ...       ...
# 95   0.823605  0.449094  0.010248  0.943658  0.669968
# 96  0.0948171  0.347374  0.090990  0.028361  0.297210
# 97  0.0184986  0.960380  0.585781  0.030061  0.663606
# 98    0.63652  0.285935  0.883017  0.772275  0.302865
# 99   0.278624  0.826616  0.377349  0.661813  0.868480
#
# [100 rows x 5 columns]

# %%
id(newdf)
# Out:
# 202881552

# %%
id(newdf1)
# Out:
# 202881552

# %%
newdf1 = newdf.copy()

# %%
id(newdf)
# Out:
# 202881552

# %%
id(newdf1)
# Out:
# 203102128

# %%
newdf.head(3)
# Out:
#           0         1         2         3         4
# 0  0.333333  0.794252  0.080251  0.929285  0.264517
# 1  0.444444  0.576179  0.856053  0.792471  0.120234
# 2  0.397942  0.836594  0.052836  0.302841  0.855034

# %%
newdf.loc[0,0]=0.55555

# %%
newdf.head(3)
# Out:
#           0         1         2         3         4
# 0   0.55555  0.794252  0.080251  0.929285  0.264517
# 1  0.444444  0.576179  0.856053  0.792471  0.120234
# 2  0.397942  0.836594  0.052836  0.302841  0.855034

# %%
newdf.columns = list("PQRST")

# %%
newdf.head()
# Out:
#           P         Q         R         S         T
# 0   0.55555  0.794252  0.080251  0.929285  0.264517
# 1  0.444444  0.576179  0.856053  0.792471  0.120234
# 2  0.397942  0.836594  0.052836  0.302841  0.855034
# 3  0.827553  0.704875  0.169747  0.435392  0.359005
# 4  0.626744  0.391912  0.809596  0.246168  0.430423

# %%
newdf.loc[0,0]=0.666666

# %%
newdf.head(2)
# Out:
#           P         Q         R         S         T         0
# 0   0.55555  0.794252  0.080251  0.929285  0.264517  0.666666
# 1  0.444444  0.576179  0.856053  0.792471  0.120234       NaN

# %%
newdf.loc[0,"P"]= 0.77777

# %%
newdf.head(2)
# Out:
#           P         Q         R         S         T         0
# 0   0.77777  0.794252  0.080251  0.929285  0.264517  0.666666
# 1  0.444444  0.576179  0.856053  0.792471  0.120234       NaN

# %%
newdf = newdf.drop(0,axis = 1)

# %%
newdf.drop(0,axis = 0)
# Out:
#             P         Q         R         S         T
# 1    0.444444  0.576179  0.856053  0.792471  0.120234
# 2    0.397942  0.836594  0.052836  0.302841  0.855034
# 3    0.827553  0.704875  0.169747  0.435392  0.359005
# 4    0.626744  0.391912  0.809596  0.246168  0.430423
# 5   0.0855984  0.140346  0.045341  0.244276  0.215553
# ..        ...       ...       ...       ...       ...
# 95   0.823605  0.449094  0.010248  0.943658  0.669968
# 96  0.0948171  0.347374  0.090990  0.028361  0.297210
# 97  0.0184986  0.960380  0.585781  0.030061  0.663606
# 98    0.63652  0.285935  0.883017  0.772275  0.302865
# 99   0.278624  0.826616  0.377349  0.661813  0.868480
#
# [99 rows x 5 columns]

# %%
newdf.loc[[1,2,3,8,9],['P','Q']]
# Out:
#           P         Q
# 1  0.444444  0.576179
# 2  0.397942  0.836594
# 3  0.827553  0.704875
# 8  0.916051  0.061548
# 9  0.852325  0.135256

# %%
newdf.loc[:,['P','Q']]
# Out:
#             P         Q
# 0     0.77777  0.794252
# 1    0.444444  0.576179
# 2    0.397942  0.836594
# 3    0.827553  0.704875
# 4    0.626744  0.391912
# ..        ...       ...
# 95   0.823605  0.449094
# 96  0.0948171  0.347374
# 97  0.0184986  0.960380
# 98    0.63652  0.285935
# 99   0.278624  0.826616
#
# [100 rows x 2 columns]

# %%
newdf.loc[[1,2,3,8,9],:]
# Out:
#           P         Q         R         S         T
# 1  0.444444  0.576179  0.856053  0.792471  0.120234
# 2  0.397942  0.836594  0.052836  0.302841  0.855034
# 3  0.827553  0.704875  0.169747  0.435392  0.359005
# 8  0.916051  0.061548  0.019920  0.873773  0.864878
# 9  0.852325  0.135256  0.100608  0.714165  0.098198

# %%
newdf.loc[newdf['P']>0.5]
# Out:
#            P         Q         R         S         T
# 0    0.77777  0.794252  0.080251  0.929285  0.264517
# 3   0.827553  0.704875  0.169747  0.435392  0.359005
# 4   0.626744  0.391912  0.809596  0.246168  0.430423
# 6   0.712177  0.130184  0.763563  0.163066  0.072062
# 7   0.894162  0.925103  0.770900  0.972718  0.250384
# 8   0.916051  0.061548  0.019920  0.873773  0.864878
# 9   0.852325  0.135256  0.100608  0.714165  0.098198
# 11  0.901159  0.781648  0.163512  0.191342  0.820992
# 12  0.588029  0.031433  0.336159  0.573297  0.843499
# 13  0.891981  0.621923  0.566023  0.485696  0.222563
# 15  0.842388  0.903863  0.512386  0.050623  0.209722
# 16  0.595128  0.434446  0.132975  0.333389  0.114192
# 17  0.751133  0.231566  0.927223  0.652761  0.098459
# 19  0.644818  0.314885  0.962601  0.022414  0.895550
# 20  0.558356  0.309681  0.817198  0.272902  0.401326
# 22  0.940738  0.785077  0.695697  0.273752  0.732412
# 24  0.545611  0.455097  0.647548  0.084172  0.534340
# ...

# %%
newdf.loc[(newdf['P']>0.5) & (newdf['Q']>newdf['P'])]
# Out:
#            P         Q         R         S         T
# 0    0.77777  0.794252  0.080251  0.929285  0.264517
# 7   0.894162  0.925103  0.770900  0.972718  0.250384
# 15  0.842388  0.903863  0.512386  0.050623  0.209722
# 27  0.812149  0.975753  0.749601  0.793639  0.021475
# 34  0.549907  0.866876  0.289523  0.291419  0.324979
# 37  0.734911  0.843168  0.537588  0.598764  0.153453
# 40  0.558663  0.805526  0.452644  0.363171  0.332972
# 56  0.639369  0.989019  0.639342  0.099161  0.572040
# 66  0.786702  0.929159  0.118062  0.620771  0.079505
# 82  0.731493  0.754325  0.342712  0.561819  0.546230
# 90  0.826729  0.977443  0.840585  0.312067  0.563425

# %%
newdf.head(2)
# Out:
#           P         Q         R         S         T
# 0   0.77777  0.794252  0.080251  0.929285  0.264517
# 1  0.444444  0.576179  0.856053  0.792471  0.120234

# %%
newdf.iloc[0,2]  # i is index
# Out:
# 0.08025099244207412

# %%
newdf.iloc[[0,1,2,5,6],[1,2]]
# Out:
#           Q         R
# 0  0.794252  0.080251
# 1  0.576179  0.856053
# 2  0.836594  0.052836
# 5  0.140346  0.045341
# 6  0.130184  0.763563

# %%
newdf.head(3)
# Out:
#           P         Q         R         S         T
# 0   0.77777  0.794252  0.080251  0.929285  0.264517
# 1  0.444444  0.576179  0.856053  0.792471  0.120234
# 2  0.397942  0.836594  0.052836  0.302841  0.855034

# %%
newdf.drop([0])
# Out:
#             P         Q         R         S         T
# 1    0.444444  0.576179  0.856053  0.792471  0.120234
# 2    0.397942  0.836594  0.052836  0.302841  0.855034
# 3    0.827553  0.704875  0.169747  0.435392  0.359005
# 4    0.626744  0.391912  0.809596  0.246168  0.430423
# 5   0.0855984  0.140346  0.045341  0.244276  0.215553
# ..        ...       ...       ...       ...       ...
# 95   0.823605  0.449094  0.010248  0.943658  0.669968
# 96  0.0948171  0.347374  0.090990  0.028361  0.297210
# 97  0.0184986  0.960380  0.585781  0.030061  0.663606
# 98    0.63652  0.285935  0.883017  0.772275  0.302865
# 99   0.278624  0.826616  0.377349  0.661813  0.868480
#
# [99 rows x 5 columns]

# %%
newdf.drop(['T'],axis= 1)
# Out:
#             P         Q         R         S
# 0     0.77777  0.794252  0.080251  0.929285
# 1    0.444444  0.576179  0.856053  0.792471
# 2    0.397942  0.836594  0.052836  0.302841
# 3    0.827553  0.704875  0.169747  0.435392
# 4    0.626744  0.391912  0.809596  0.246168
# ..        ...       ...       ...       ...
# 95   0.823605  0.449094  0.010248  0.943658
# 96  0.0948171  0.347374  0.090990  0.028361
# 7   0.894162  0.925103  0.770900  0.972718  0.250384

# %%
newdf.reset_index(drop=True,inplace = True)

# %%
newdf.head()
# Out:
#            P         Q         R         S         T
# 0    0.77777  0.794252  0.080251  0.929285  0.264517
# 1   0.626744  0.391912  0.809596  0.246168  0.430423
# 2  0.0855984  0.140346  0.045341  0.244276  0.215553
# 3   0.712177  0.130184  0.763563  0.163066  0.072062
# 4   0.894162  0.925103  0.770900  0.972718  0.250384

# %%
newdf.isnull()
# Out:
#         P      Q      R      S      T
# 0   False  False  False  False  False
# 1   False  False  False  False  False
# 2   False  False  False  False  False
# 3   False  False  False  False  False
# 4   False  False  False  False  False
# ..    ...    ...    ...    ...    ...
# 92  False  False  False  False  False
# 93  False  False  False  False  False
# 94  False  False  False  False  False
# 95  False  False  False  False  False
# 96  False  False  False  False  False
#
# [97 rows x 5 columns]

# %%
newdf.loc[:,'P']=8

# %%
newdf.head()
# Out:
#    P         Q         R         S         T
# 0  8  0.794252  0.080251  0.929285  0.264517
# 1  8  0.391912  0.809596  0.246168  0.430423
# 2  8  0.140346  0.045341  0.244276  0.215553
# 3  8  0.130184  0.763563  0.163066  0.072062
# 4  8  0.925103  0.770900  0.972718  0.250384

# %%
newdf.shape
# Out:
# (97, 5)

# %%
df.shape
# Out:
# (4, 3)

# %%
newdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 97 entries, 0 to 96
# Data columns (total 5 columns):
# P    97 non-null int64
# Q    97 non-null float64
# R    97 non-null float64
# S    97 non-null float64
# T    97 non-null float64
# dtypes: float64(4), int64(1)
# memory usage: 3.9 KB

# %%
newdf.notnull()
# Out:
#        P     Q     R     S     T
# 0   True  True  True  True  True
# 1   True  True  True  True  True
# 2   True  True  True  True  True
# 3   True  True  True  True  True
# 4   True  True  True  True  True
# ..   ...   ...   ...   ...   ...
# 92  True  True  True  True  True
# 93  True  True  True  True  True
# 94  True  True  True  True  True
# 95  True  True  True  True  True
# 96  True  True  True  True  True
#
# [97 rows x 5 columns]

# %%
newdf.corr
# Out:
# <bound method DataFrame.corr of     P         Q         R         S         T
# 0   8  0.794252  0.080251  0.929285  0.264517
# 1   8  0.391912  0.809596  0.246168  0.430423
# 2   8  0.140346  0.045341  0.244276  0.215553
# 3   8  0.130184  0.763563  0.163066  0.072062
# 4   8  0.925103  0.770900  0.972718  0.250384
# .. ..       ...       ...       ...       ...
# 92  8  0.449094  0.010248  0.943658  0.669968
# 93  8  0.347374  0.090990  0.028361  0.297210
# 94  8  0.960380  0.585781  0.030061  0.663606
# 95  8  0.285935  0.883017  0.772275  0.302865
# 96  8  0.826616  0.377349  0.661813  0.868480
#
# [97 rows x 5 columns]>

# %%
newdf.std
# Out:
# <bound method DataFrame.std of     P         Q         R         S         T
# 0   8  0.794252  0.080251  0.929285  0.264517
# 1   8  0.391912  0.809596  0.246168  0.430423
# 2   8  0.140346  0.045341  0.244276  0.215553
# 3   8  0.130184  0.763563  0.163066  0.072062
# 4   8  0.925103  0.770900  0.972718  0.250384
# .. ..       ...       ...       ...       ...
# 92  8  0.449094  0.010248  0.943658  0.669968
# 93  8  0.347374  0.090990  0.028361  0.297210
# 94  8  0.960380  0.585781  0.030061  0.663606
# 95  8  0.285935  0.883017  0.772275  0.302865
# 96  8  0.826616  0.377349  0.661813  0.868480
#
# [97 rows x 5 columns]>
